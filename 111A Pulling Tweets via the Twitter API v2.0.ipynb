# %% [markdown]
# # 1 Define Functions to Interact with the Twitter API

# %%
import requests 
import json 
import pandas as pd

# imports the twitter_secrets python file in which we store the twitter API keys
from twitter_secrets import twitter_secrets as ts

# puts the bearer token in the request header
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers
        
# sets the rules on which tweets to retrieve    
def set_rules(headers, delete, bearer_token, rules):
    payload = {"add": rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    
# retrieves the current set of rules from the API     
def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

# tells the API to delete our current rule configuration 
def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

# starts the stream, iterates through the lines of the response and for each line calls the save_tweets function
def get_stream(headers, set, bearer_token, expansions, fields):
    data = []
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream" + expansions + fields, headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    i = 0
    for response_line in response.iter_lines():
        i += 1
        if i == max_results:
            break
        else:
            json_response = json.loads(response_line)
            #print(json.dumps(json_response, indent=4, sort_keys=True))
            try:
                save_tweets(json_response)
            except (json.JSONDecodeError, KeyError) as err:
                # In case the JSON fails to decode, we skip this tweet
                print(f"{i}/{max_results}: ERROR: encountered a problem with a line of data... \n")
                continue

# appends information from tweets to a dataframe                
def save_tweets(tweet):
    print(json.dumps(tweet, indent=4, sort_keys=True))
    data = tweet['data']
    public_metrics = data['public_metrics']
    tweet_list.append([data['id'], data['author_id'], data['created_at'], data['text'], public_metrics['like_count']])
# Out:
# {"data": [{"id": "1346440522056003585", "value": "dog has:images", "tag": "dog pictures"}], "meta": {"sent": "2021-05-02T14:36:02.989Z"}}
# {"meta": {"sent": "2021-05-02T14:36:04.226Z", "summary": {"deleted": 1, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1388864873803702274"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1388864873803702275"}], "meta": {"sent": "2021-05-02T14:36:05.398Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "author_id": "1355182694997622785",
#         "created_at": "2021-05-02T14:35:56.000Z",
#         "id": "1388864840089968646",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 1
#         },
#         "text": "RT @annadegirona1: vols fer un regal original? roses fetes a m\u00e0 - en ganxet - artesania\n\nhttps://t.co/DSh5Ppu5Ho\n\n roses 5 euros - cistella\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388862928825176068",
#                 "3_1388862994923200513",
#                 "3_1388863608239452164",
#                 "3_1388863625620643842"
#             ]
#         },
#         "author_id": "1359719162415771648",
#         "created_at": "2021-05-02T14:35:56.000Z",
#         "id": "1388864842119847938",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "CAT FIGHT\ud83d\udc08\u2694\ufe0f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\uff5e\uff01\nTwitter\u306e\u307b\u3093\u308f\u304b\u7cfb\u3068\u306f\u30ae\u30e3\u30c3\u30d7\u306e\u3042\u308b\u7a4d\u6975\u7684\u306atomo\u3061\u3083\u3093\u3068\u3001\u307e\u3063\u3059\u3050\u724c\u3092\u66f2\u3052\u308b\u3082\u306e\u306e\u3075\u30af\u30ec\u30a2\u30e9\u3055\u3093\u3068\u3001\u7d42\u59cb\u51b7\u9759\u306b\u62bc\u3057\u5f15\u304d\u3059\u308b\u3077\u30fc\u3061\u3083\u3093\u3068\u3001\uff11\u5217\u76ee\u7d42\u308f\u308b\u3068\u9014\u7aef\u306b\u30d3\u30d3\u308a\u3060\u3059\u9727\u306e\u68ee\u3067\u306e\u6109\u5feb\u306a\u5bfe\u5c40\u3067\u3057\u305f\ud83d\udc95\n\u30c8\u30c3\u30d7\u53d6\u308c\u306a\u304b\u3063\u305f\u306e\u3067\u6b21\u56de\u30ea\u30d9\u30f3\u30b8\u3058\u3083\uff5e\uff01 https://t.co/zGVr5E8y5r"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1288738449189732352",
#         "created_at": "2021-05-02T14:35:57.000Z",
#         "id": "1388864843684499458",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 9
#         },
#         "text": "RT @ROLDAOrg: Another horrific case discovered this week. A little dog with a wire around his body, ingrown in his flesh.I cannot imagine t\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702275,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388732556607205378"
#             ]
#         },
#         "author_id": "38265398",
#         "created_at": "2021-05-02T14:35:57.000Z",
#         "id": "1388864843663364097",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 497
#         },
#         "text": "RT @mikegalsworthy: The dog\u2019s expression says it all. https://t.co/fjKIqXCgJ8"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702275,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388864842027749378"
#             ]
#         },
#         "author_id": "1472033731",
#         "created_at": "2021-05-02T14:35:57.000Z",
#         "id": "1388864843701174275",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "C1 (F) - PSG - Olivier Echouafni (PSG) apr\u00e8s l'\u00e9limination contre le Bar\u00e7a\u00a0:\u2026 https://t.co/ppdwLPDFBh https://t.co/5lz0i0qSqx"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388862930968485894",
#                 "3_1388862930972667904",
#                 "3_1388862931073335298"
#             ]
#         },
#         "author_id": "137965196",
#         "created_at": "2021-05-02T14:35:57.000Z",
#         "id": "1388864844607090691",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 77
#         },
#         "text": "RT @19951230vVvVvVv: \ucc44\ub110 \uc2ed\uc624\uc57c \uc778\uc2a4\ud0c0 / \uc778\uc2a4\ud0c0 \uc2a4\ud1a0\ub9ac\n\nhttps://t.co/VLy2rI4juz\n\nhttps://t.co/4no3CWZWMn\n\nhttps://t.co/YJOkEfGM4H https://t.co/oF5iIYHgvJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1167047966730752002",
#         "created_at": "2021-05-02T14:35:58.000Z",
#         "id": "1388864846947504131",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 144
#         },
#         "text": "RT @HkanhpaSadan: Myitkyina Journal's publication licence has been revoked by Terrorist coup group. An another act from the mad dog MAL. @N\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702275,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388805532568326155"
#             ]
#         },
#         "author_id": "1260687295411138560",
#         "created_at": "2021-05-02T14:35:58.000Z",
#         "id": "1388864846855172098",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 221
#         },
#         "text": "RT @linandhers: #\u0e42\u0e17\u0e42\u0e01\u0e30 #\u751a\u4e94 \u0d2f c\u0336u\u0336r\u0336s\u0336e\u0336 cat user\n\n\u0e40\u0e25\u0e35\u0e49\u0e22\u0e07\u0e22\u0e32\u0e01\u0e01\u0e27\u0e48\u0e32\u0e2b\u0e19\u0e2d\u0e19 10 \u0e40\u0e17\u0e48\u0e32\u2755 https://t.co/0mzPbpf8to"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "114043600",
#         "created_at": "2021-05-02T14:35:58.000Z",
#         "id": "1388864847094317063",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 3
#         },
#         "text": "RT @Lone: ANCIENT ASTRONAUTS\nw/ LONE\n\nBack on @noodsradio for the fourth transmission tonight 20:00 - 22:00 UK time\n\nTunes from Madlib, BOC\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702275,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388864831638355970"
#             ]
#         },
#         "author_id": "591623368",
#         "created_at": "2021-05-02T14:35:58.000Z",
#         "id": "1388864848361136129",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Fora Colau! Cartell de la manifestaci\u00f3 contra Colau a Barcelona:(d\u2019https://t.co/XyLHVJu5PO) https://t.co/iZwCQQGPmc"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "138654861",
#         "created_at": "2021-05-02T14:35:58.000Z",
#         "id": "1388864849975910404",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "This. https://t.co/UtD4UoXWB3"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388862106196381698",
#                 "3_1388862111170826245"
#             ]
#         },
#         "author_id": "1380153896123969543",
#         "created_at": "2021-05-02T14:35:59.000Z",
#         "id": "1388864854530969600",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 2
#         },
#         "text": "RT @confusedtotem: Blessing the tl with my sleepy cat https://t.co/B7m53Y29im"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388678246477320199",
#                 "3_1388678246481506309"
#             ]
#         },
#         "author_id": "1178016209809416192",
#         "created_at": "2021-05-02T14:36:00.000Z",
#         "id": "1388864858020589570",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 56
#         },
#         "text": "RT @MikeCatSU: cat https://t.co/daC50LQclJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1341864282481430529",
#         "created_at": "2021-05-02T14:36:00.000Z",
#         "id": "1388864858666512385",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "also mineshaft in the distance whoohoo https://t.co/2YkMHy62G8"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702274,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388864838718394369"
#             ]
#         },
#         "author_id": "1170354033577680896",
#         "created_at": "2021-05-02T14:36:01.000Z",
#         "id": "1388864860633636865",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Dog selfie. https://t.co/qC409CGuKV"
#     },
#     "matching_rules": [
#         {
#             "id": 1388864873803702275,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1374944194763005955",
#         "created_at": "2021-05-02T14:36:02.000Z",
#         "id": "1388864863896625157",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 144
#         },
#         "text": "RT @HkanhpaSadan: Myitkyina Journal's publication licence has been revoked by Terrorist coup group. An another act from the mad dog MAL. @N\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 
# 5   RT @19951230vVvVvVv: 채널 십오야 인스타 / 인스타 스토리\n\nh...           0
# 6   RT @HkanhpaSadan: Myitkyina Journal's publicat...           0
# 7   RT @linandhers: #โทโกะ #甚五 യ c̶u̶r̶s̶e̶ cat us...           0
# 8   RT @Lone: ANCIENT ASTRONAUTS\nw/ LONE\n\nBack ...           0
# 9   Fora Colau! Cartell de la manifestació contra ...           0
# 10                      This. https://t.co/UtD4UoXWB3           0
# 11  RT @confusedtotem: Blessing the tl with my sle...           0
# 12         RT @MikeCatSU: cat https://t.co/daC50LQclJ           0
# 13  also mineshaft in the distance whoohoo https:/...           0
# 14                Dog selfie. https://t.co/qC409CGuKV           0
# 15  RT @HkanhpaSadan: Myitkyina Journal's publicat...           0
# 16  RT @nonoworks: Cat hoodie🐱💕\n#Zelda https://t....           0
# 17  @yuna65671780 2枚目のあざとcatアイめちゃくちゃ可愛いのでおすすめです、、！...           0
# 18  RT @AdoptionsUk: Please retweet  FIND ALFIE A ...           0

# %% [markdown]
# # 2 Subscribe to the Tweet Streaming Service

# %%
# the max number of tweets that will be returned
max_results = 20

# You can adjust the rules if needed
search_rules = [
    {"value": "dog has:images", "tag": "dog pictures", "lang": "en"},
    {"value": "cat has:images -grumpy", "tag": "cat pictures", "lang": "en"},
]

# defines the fields which we want to retrieve
tweet_fields = "?tweet.fields=attachments,author_id,created_at,public_metrics"

# we only retrieve the tweet object, but if we wanted to retrieve other objects (e.g., media), we would add them to the expansions string
expansions = ""
tweet_list = []

bearer_token = ts.BEARER_TOKEN
headers = create_headers(bearer_token)
rules = get_rules(headers, bearer_token)
delete = delete_all_rules(headers, bearer_token, rules)
set = set_rules(headers, delete, bearer_token, search_rules)
get_stream(headers, set, bearer_token, expansions, tweet_fields)

df = pd.DataFrame (tweet_list, columns = ['tweetid', 'author_id' , 'created_at', 'text', 'like_count'])
df
# Out:
# {"data": [{"id": "1388864873803702274", "value": "cat has:images -grumpy", "tag": "cat pictures"}, {"id": "1388864873803702275", "value": "dog has:images", "tag": "dog pictures"}], "meta": {"sent": "2021-05-02T14:38:14.580Z"}}
# {"meta": {"sent": "2021-05-02T14:38:15.878Z", "summary": {"deleted": 2, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1388865425992294400"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1388865425992294401"}], "meta": {"sent": "2021-05-02T14:38:17.171Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "author_id": "1228785355077214208",
#         "created_at": "2021-05-02T14:38:07.000Z",
#         "id": "1388865388981592066",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 25
#         },
#         "text": "RT @Mr_UsmanAnsari: Famous British Pop Singer cat stevens. December 1977, Stevens converted to Islam and adopted the name Yusuf Islam. In 1\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "824700720876290052",
#         "created_at": "2021-05-02T14:38:07.000Z",
#         "id": "1388865389883449345",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 4
#         },
#         "text": "RT @Cat_Kapow: \ud83c\udd98Today #MakeADifference &amp; raise food for 105 #RescueDogs in \ud83c\uddf2\ud83c\udde6#Morocco \ud83d\udc36\ud83d\ude3fDog Shelter asks for food for #dogs \ud83d\ude40They have none\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388856353163079684"
#             ]
#         },
#         "author_id": "935446244989603840",
#         "created_at": "2021-05-02T14:38:07.000Z",
#         "id": "1388865390277652480",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 260
#         },
#         "text": "RT @somemememeya: cat\n#\u30a2\u30fc\u30af\u30ca\u30a4\u30c4 https://t.co/eQyD8t6P4P"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "4785486634",
#         "created_at": "2021-05-02T14:38:07.000Z",
#         "id": "1388865391758303234",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 9
#         },
#         "text": "RT @ConsellxRepComp: Actualment el Consell per la Rep\u00fablica Catalana compta amb 96.933 persones registrades. #ComptadorRegistresConsell\n\nUn\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1387377606329307139"
#             ]
#         },
#         "author_id": "1156256884644597761",
#         "created_at": "2021-05-02T14:38:08.000Z",
#         "id": "1388865393675186178",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 3196
#         },
#         "text": "RT @k_katertot: lol this dog needs to *log off* https://t.co/ZdDUcim4Rj"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388204392688627715"
#             ]
#         },
#         "author_id": "469406310",
#         "created_at": "2021-05-02T14:38:08.000Z",
#         "id": "1388865394165882880",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 25649
#         },
#         "text": "RT @3CC0__: i-Dog by McDonald's (2007) https://t.co/KGLeSYgaHC"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388828108015341568"
#             ]
#         },
#         "author_id": "4761946880",
#         "created_at": "2021-05-02T14:38:10.000Z",
#         "id": "1388865400503300101",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 9
#         },
#         "text": "RT @minuet_nenosuke: \u3082\u3075\u308a\u5f85\u3061\u306e\u958b\u811a\n#\u732b #\u30de\u30f3\u30c1\u30ab\u30f3 #\u30df\u30cc\u30a8\u30c3\u30c8 #\u732b\u306e\u3044\u308b\u66ae\u3089\u3057 #cat #\u732b\u597d\u304d\u3055\u3093\u3068\u7e4b\u304c\u308a\u305f\u3044 https://t.co/74ApvC38wo"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388696993736839173"
#             ]
#         },
#         "author_id": "890751484945547264",
#         "created_at": "2021-05-02T14:38:10.000Z",
#         "id": "1388865402709504000",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 91
#         },
#         "text": "RT @mimiatiny: \u2018Black Cat Nero' Performance video \u0e02\u0e2d\u0e07\u0e40\u0e2d\u0e17\u0e35\u0e0b\u0e21\u0e35\u0e22\u0e2d\u0e14\u0e27\u0e34\u0e27 10M \u0e41\u0e25\u0e49\u0e27 \ud83c\udf89\ud83c\udf89\ud83c\udf89 https://t.co/a1ZeARTJOa"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1160282851750948864",
#         "created_at": "2021-05-02T14:38:11.000Z",
#         "id": "1388865404987129858",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 1
#         },
#         "text": "RT @Seiurus: Please remember me this way: enjoying a local beer with dear friends, COVID hair blowing in the OK breeze, a sweet dog licking\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388862930968485894",
#                 "3_1388862930972667904",
#                 "3_1388862931073335298"
#             ]
#         },
#         "author_id": "1246940543415767041",
#         "created_at": "2021-05-02T14:38:11.000Z",
#         "id": "1388865405603573761",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 96
#         },
#         "text": "RT @19951230vVvVvVv: \ucc44\ub110 \uc2ed\uc624\uc57c \uc778\uc2a4\ud0c0 / \uc778\uc2a4\ud0c0 \uc2a4\ud1a0\ub9ac\n\nhttps://t.co/VLy2rI4juz\n\nhttps://t.co/4no3CWZWMn\n\nhttps://t.co/YJOkEfGM4H https://t.co/oF5iIYHgvJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388826369975455746"
#             ]
#         },
#         "author_id": "2162498252",
#         "created_at": "2021-05-02T14:38:11.000Z",
#         "id": "1388865405695905792",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 27
#         },
#         "text": "RT @lilium_amor: #Nora_Cat\n\u307f\u305f\u3089\u3057\u304c\u3044\u3044\u304d\u3083\u3063\u3068 https://t.co/UUuQzEG1S6"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1113974608733114368",
#         "created_at": "2021-05-02T14:38:11.000Z",
#         "id": "1388865406903930897",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Me but with my dog https://t.co/uXiQXLHKwn"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388856353163079684"
#             ]
#         },
#         "author_id": "1267749145957134337",
#         "created_at": "2021-05-02T14:38:11.000Z",
#         "id": "1388865408074059781",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 262
#         },
#         "text": "RT @somemememeya: cat\n#\u30a2\u30fc\u30af\u30ca\u30a4\u30c4 https://t.co/eQyD8t6P4P"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1331219241421467650",
#         "created_at": "2021-05-02T14:38:12.000Z",
#         "id": "1388865412620820486",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 145
#         },
#         "text": "RT @happwheee: i rlly rlly love wheein's instagram bc it doesn't feel like a celebrity/kpop idol's ig but it's more like your typical frien\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "2311874144",
#         "created_at": "2021-05-02T14:38:13.000Z",
#         "id": "1388865413883310081",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 39
#         },
#         "text": "RT @BearBertthe: Bert in his rebellious teenage years\nAnti social behaviour dog \ud83e\udd2c\nHanging about street corners at the weekend, in his hoody\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388853599510450177"
#             ]
#         },
#         "author_id": "1363316109957599232",
#         "created_at": "2021-05-02T14:38:14.000Z",
#         "id": "1388865417775665153",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 21
#         },
#         "text": "RT @Xytora: It's mae the funny cat\n@Chip_at_Night https://t.co/KBkgtN1SKH"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294400,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1388865416890515456"
#             ]
#         },
#         "author_id": "559108687",
#         "created_at": "2021-05-02T14:38:14.000Z",
#         "id": "1388865420514390019",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "@roody32609 Great name! This is our Birdie the bird dog as well \u263a\ufe0f https://t.co/rbXnpi0SBW"
#     },
#     "matching_rules": [
#         {
#             "id": 1388865425992294401,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "976846828963532803",
#         "created_at": "2021-05-02T14:38:15.000Z",
#         "id": "1388865421772738560",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count":