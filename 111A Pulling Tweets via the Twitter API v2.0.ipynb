# %% [markdown]
# # 1 Define Functions to Interact with the Twitter API

# %%
import requests 
import json 
import pandas as pd

# imports the twitter_secrets python file in which we store the twitter API keys
# place the twitter_secrets file under <User>/anaconda3/Lib
from twitter_secrets import twitter_secrets as ts

# puts the bearer token in the request header
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers
        
# sets the rules on which tweets to retrieve    
def set_rules(headers, delete, bearer_token, rules):
    payload = {"add": rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    
# retrieves the current set of rules from the API     
def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

# tells the API to delete our current rule configuration 
def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

# starts the stream, iterates through the lines of the response and for each line calls the save_tweets function
def get_stream(headers, set, bearer_token, expansions, fields):
    data = []
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream" + expansions + fields, headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    i = 0
    for response_line in response.iter_lines():
        i += 1
        if i == max_results:
            break
        else:
            json_response = json.loads(response_line)
            #print(json.dumps(json_response, indent=4, sort_keys=True))
            try:
                save_tweets(json_response)
            except (json.JSONDecodeError, KeyError) as err:
                # In case the JSON fails to decode, we skip this tweet
                print(f"{i}/{max_results}: ERROR: encountered a problem with a line of data... \n")
                continue

# appends information from tweets to a dataframe                
def save_tweets(tweet):
    print(json.dumps(tweet, indent=4, sort_keys=True))
    data = tweet['data']
    public_metrics = data['public_metrics']
    tweet_list.append([data['id'], data['author_id'], data['created_at'], data['text'], public_metrics['like_count']])

# %% [markdown]
# # 2 Subscribe to the Tweet Streaming Service

# %%
# the max number of tweets that will be returned
max_results = 20

# You can adjust the rules if needed
search_rules = [
    {"value": "dog has:images", "tag": "dog pictures", "lang": "en"},
    {"value": "cat has:images -grumpy", "tag": "cat pictures", "lang": "en"},
]

# defines the fields which we want to retrieve
tweet_fields = "?tweet.fields=attachments,author_id,created_at,public_metrics"

# we only retrieve the tweet object, but if we wanted to retrieve other objects (e.g., media), we would add them to the expansions string
expansions = ""
tweet_list = []

bearer_token = ts.BEARER_TOKEN
headers = create_headers(bearer_token)
rules = get_rules(headers, bearer_token)
delete = delete_all_rules(headers, bearer_token, rules)
set = set_rules(headers, delete, bearer_token, search_rules)
get_stream(headers, set, bearer_token, expansions, tweet_fields)

df = pd.DataFrame (tweet_list, columns = ['tweetid', 'author_id' , 'created_at', 'text', 'like_count'])
df
# Out:
# {"data": [{"id": "1388866121256869898", "value": "dog has:images", "tag": "dog pictures"}], "meta": {"sent": "2021-05-09T14:38:06.574Z"}}
# {"meta": {"sent": "2021-05-09T14:38:07.827Z", "summary": {"deleted": 1, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1391402107169918977"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1391402107169918976"}], "meta": {"sent": "2021-05-09T14:38:09.437Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "author_id": "1381223929226743812",
#         "created_at": "2021-05-09T14:37:59.000Z",
#         "id": "1391402072084385798",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 437
#         },
#         "text": "RT @CiervoKing: $50 in 3 hours \ud83d\udc97\n\n\u25aa\ufe0fRetweet this\n\u25aa\ufe0fGo to this telegram &amp; VOTE for (COVID DOG) https://t.co/ePCYP9iQs6\n\u25aa\ufe0fShow proof https://\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918976,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "1168472275",
#         "created_at": "2021-05-09T14:37:59.000Z",
#         "id": "1391402073300815876",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 372
#         },
#         "text": "RT @DogsofTooting: Let\u2019s #GetTonyHome missing from back garden was he taken . Please people of  #spratton #Northamptonshire #Nn6 we need yo\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918976,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391402070310330369"
#             ]
#         },
#         "author_id": "857643958205386753",
#         "created_at": "2021-05-09T14:37:59.000Z",
#         "id": "1391402073065992196",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Ciftlikbank, ka\u00e7an coinci derken bu adama g\u00fcvenip var\u0131n\u0131 yokunu dog coin e yat\u0131ran batar abi :)))) \nMant\u0131kl\u0131 ilerleyin nereye yat\u0131r\u0131m yaparsan\u0131z yap\u0131n k\u0131sa yoldan zenginlik diye bir\u015fey yok . https://t.co/TbzVeKvJOB"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918976,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391119302841929730"
#             ]
#         },
#         "author_id": "1388020295831748612",
#         "created_at": "2021-05-09T14:38:00.000Z",
#         "id": "1391402074571747335",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Happy National Dog Mom\u2019s Day \ud83c\udf89\n#CorgiCrew #Corgi https://t.co/bq2ppkAeWL"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918976,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391400198476271618"
#             ]
#         },
#         "author_id": "14088938",
#         "created_at": "2021-05-09T14:38:00.000Z",
#         "id": "1391402074584150024",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "Salut alerta del perill de relaxar-se abans d'hora despr\u00e9s de veure les celebracions del fi de l'estat d'alarma https://t.co/79Ac0O7vLO https://t.co/EmORSbX8VJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391396777589280772",
#                 "3_1391396777589235713"
#             ]
#         },
#         "author_id": "266580353",
#         "created_at": "2021-05-09T14:38:01.000Z",
#         "id": "1391402080808615942",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 35
#         },
#         "text": "RT @mondomascots: Nyantaro, a cat with a headband, is the mascot of Kahoku City. https://t.co/ewE3uVff0Y"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391352059639775234",
#                 "3_1391352059614711809"
#             ]
#         },
#         "author_id": "706153880011182080",
#         "created_at": "2021-05-09T14:38:01.000Z",
#         "id": "1391402081383174147",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 14
#         },
#         "text": "RT @teenyjimi: cant forget for every cat pic theres a jimin pic https://t.co/jM45yMRE35"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391359707856650240"
#             ]
#         },
#         "author_id": "1209540791074480128",
#         "created_at": "2021-05-09T14:38:02.000Z",
#         "id": "1391402084470296581",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 9
#         },
#         "text": "RT @Love4Liam_: My dog is a Liam stan https://t.co/Dk7WbUtRPA"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918976,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391229090754023428"
#             ]
#         },
#         "author_id": "958405668247044096",
#         "created_at": "2021-05-09T14:38:03.000Z",
#         "id": "1391402088803012609",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 1216
#         },
#         "text": "RT @allisonsmithart: A Man and His Cat is a ridiculously wholesome manga https://t.co/yNJPYz10E5"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "author_id": "805807552038637570",
#         "created_at": "2021-05-09T14:38:03.000Z",
#         "id": "1391402089356611586",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 6
#         },
#         "text": "RT @salvasapedraza: Invitaci\u00f3n a PLATAFORMA DE FORMACI\u00d3N CONTINUADA DE DIAGN\u00d3STICO Y TRATAMIENTO POR LA IMAGEN DE GIRONA. 10 al 14 de Mayo\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391402087787892738"
#             ]
#         },
#         "author_id": "1328900782259781634",
#         "created_at": "2021-05-09T14:38:04.000Z",
#         "id": "1391402090803589122",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 0
#         },
#         "text": "hello everyone pls look at my cat!! https://t.co/TUKDY8e3Zc"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "attachments": {
#             "media_keys": [
#                 "3_1391372403499020289"
#             ]
#         },
#         "author_id": "2414796438",
#         "created_at": "2021-05-09T14:38:04.000Z",
#         "id": "1391402092162596865",
#         "public_metrics": {
#             "like_count": 0,
#             "quote_count": 0,
#             "reply_count": 0,
#             "retweet_count": 9
#         },
#         "text": "RT @alex_le_bars: \ud83c\uddea\ud83c\uddf8 Espagne : \u26c8\ufe0f #Mammatus \u00e0 Llobera dans la province de L\u00e9rida ce dimanche midi \n\n(\ud83d\udcf7 @AMR_CAT) https://t.co/ucJ7EFYGiW"
#     },
#     "matching_rules": [
#         {
#             "id": 1391402107169918977,
#             "tag": "cat pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2445e2e2c03f> in <module>
#      20 delete = delete_all_rules(headers, bearer_token, rules)
#      21 set = set_rules(headers, delete, bearer_token, search_rules)
# ---> 22 get_stream(headers, set, bearer_token, expansions, tweet_fields)
#      23
#      24 df = pd.DataFrame (tweet_list, columns = ['tweetid', 'author_id' , 'created_at', 'text', 'like_count'])
#
# <ipython-input-1-216fbc120efb> in get_stream(headers, set, bearer_token, expansions, fields)
#      71         )
#      72     i = 0
# ---> 73     for response_line in response.iter_lines():
#      74         i += 1
#      75         if i == max_results:
#
# ~\anaconda3\lib\site-packages\requests\models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795         pending = None
#     796
# --> 797         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     798
#     799             if pending is not None:
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
